# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding
from ch04.negative_sampling_layer import NegativeSamplingLoss


class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 重みの初期化
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # レイヤの生成
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embeddingレイヤを使用
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # すべての重みと勾配をリストにまとめる
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # メンバ変数に単語の分散表現を設定
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common import config
# GPUで実行する場合は、下記のコメントアウトを消去（要cupy）
# ===============================================
# config.GPU = True
# ===============================================
from common.np import *
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from cbow import CBOW
from skip_gram import SkipGram
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb


# ハイパーパラメータの設定
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# モデルなどの生成
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 学習開始
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 後ほど利用できるように、必要なデータを保存
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# Downloading ptb.train.txt ...
# Done
# | epoch 1 |  iter 1 / 9295 | time 0[s] | loss 4.16
# | epoch 1 |  iter 21 / 9295 | time 1[s] | loss 4.16
# | epoch 1 |  iter 41 / 9295 | time 2[s] | loss 4.15
# | epoch 1 |  iter 61 / 9295 | time 4[s] | loss 4.12
# | epoch 1 |  iter 81 / 9295 | time 5[s] | loss 4.04
# | epoch 1 |  iter 101 / 9295 | time 6[s] | loss 3.92
# | epoch 1 |  iter 121 / 9295 | time 7[s] | loss 3.78
# | epoch 1 |  iter 141 / 9295 | time 9[s] | loss 3.62
# | epoch 1 |  iter 161 / 9295 | time 10[s] | loss 3.49
# | epoch 1 |  iter 181 / 9295 | time 11[s] | loss 3.37
# | epoch 1 |  iter 201 / 9295 | time 13[s] | loss 3.24
# | epoch 1 |  iter 221 / 9295 | time 14[s] | loss 3.15
# | epoch 1 |  iter 241 / 9295 | time 15[s] | loss 3.06
# | epoch 1 |  iter 261 / 9295 | time 16[s] | loss 3.03
# | epoch 1 |  iter 281 / 9295 | time 18[s] | loss 2.96
# | epoch 1 |  iter 301 / 9295 | time 19[s] | loss 2.92
# | epoch 1 |  iter 321 / 9295 | time 20[s] | loss 2.86
# | epoch 1 |  iter 341 / 9295 | time 22[s] | loss 2.85
# | epoch 1 |  iter 361 / 9295 | time 23[s] | loss 2.80
# | epoch 1 |  iter 381 / 9295 | time 24[s] | loss 2.79
# | epoch 1 |  iter 401 / 9295 | time 26[s] | loss 2.77
# | epoch 1 |  iter 421 / 9295 | time 27[s] | loss 2.74
# | epoch 1 |  iter 441 / 9295 | time 28[s] | loss 2.74
# | epoch 1 |  iter 461 / 9295 | time 30[s] | loss 2.73
# | epoch 1 |  iter 481 / 9295 | time 31[s] | loss 2.70
# | epoch 1 |  iter 501 / 9295 | time 32[s] | loss 2.69
# | epoch 1 |  iter 521 / 9295 | time 33[s] | loss 2.67
# | epoch 1 |  iter 541 / 9295 | time 35[s] | loss 2.68
# | epoch 1 |  iter 561 / 9295 | time 36[s] | loss 2.64
# | epoch 1 |  iter 581 / 9295 | time 37[s] | loss 2.66
# | epoch 1 |  iter 601 / 9295 | time 38[s] | loss 2.66
# | epoch 1 |  iter 621 / 9295 | time 40[s] | loss 2.63
# | epoch 1 |  iter 641 / 9295 | time 41[s] | loss 2.68
# | epoch 1 |  iter 661 / 9295 | time 42[s] | loss 2.62
# | epoch 1 |  iter 681 / 9295 | time 44[s] | loss 2.66
# | epoch 1 |  iter 701 / 9295 | time 45[s] | loss 2.62
# | epoch 1 |  iter 721 / 9295 | time 46[s] | loss 2.60
# | epoch 1 |  iter 741 / 9295 | time 47[s] | loss 2.63
# | epoch 1 |  iter 761 / 9295 | time 49[s] | loss 2.60
# | epoch 1 |  iter 781 / 9295 | time 51[s] | loss 2.62
# | epoch 1 |  iter 801 / 9295 | time 52[s] | loss 2.61
# | epoch 1 |  iter 821 / 9295 | time 54[s] | loss 2.59
# | epoch 1 |  iter 841 / 9295 | time 55[s] | loss 2.59
# | epoch 1 |  iter 861 / 9295 | time 56[s] | loss 2.59
# | epoch 1 |  iter 881 / 9295 | time 58[s] | loss 2.57
# | epoch 1 |  iter 901 / 9295 | time 59[s] | loss 2.57
# | epoch 1 |  iter 921 / 9295 | time 60[s] | loss 2.58
# | epoch 1 |  iter 941 / 9295 | time 62[s] | loss 2.58
# | epoch 1 |  iter 961 / 9295 | time 63[s] | loss 2.57
# | epoch 1 |  iter 981 / 9295 | time 64[s] | loss 2.55
# | epoch 1 |  iter 1001 / 9295 | time 65[s] | loss 2.54
# | epoch 1 |  iter 1021 / 9295 | time 66[s] | loss 2.56
# | epoch 1 |  iter 1041 / 9295 | time 68[s] | loss 2.56
# | epoch 1 |  iter 1061 / 9295 | time 69[s] | loss 2.56
# | epoch 1 |  iter 1081 / 9295 | time 70[s] | loss 2.56
# | epoch 1 |  iter 1101 / 9295 | time 72[s] | loss 2.54
# | epoch 1 |  iter 1121 / 9295 | time 73[s] | loss 2.55
# | epoch 1 |  iter 1141 / 9295 | time 75[s] | loss 2.56
# | epoch 1 |  iter 1161 / 9295 | time 76[s] | loss 2.53
# | epoch 1 |  iter 1181 / 9295 | time 77[s] | loss 2.56
# | epoch 1 |  iter 1201 / 9295 | time 79[s] | loss 2.53
# | epoch 1 |  iter 1221 / 9295 | time 80[s] | loss 2.54
# | epoch 1 |  iter 1241 / 9295 | time 81[s] | loss 2.55
# | epoch 1 |  iter 1261 / 9295 | time 82[s] | loss 2.56
# | epoch 1 |  iter 1281 / 9295 | time 84[s] | loss 2.51
# | epoch 1 |  iter 1301 / 9295 | time 85[s] | loss 2.54
# | epoch 1 |  iter 1321 / 9295 | time 86[s] | loss 2.53
# | epoch 1 |  iter 1341 / 9295 | time 87[s] | loss 2.55
# | epoch 1 |  iter 1361 / 9295 | time 89[s] | loss 2.52
# | epoch 1 |  iter 1381 / 9295 | time 90[s] | loss 2.53
# | epoch 1 |  iter 1401 / 9295 | time 91[s] | loss 2.52
# | epoch 1 |  iter 1421 / 9295 | time 93[s] | loss 2.52
# | epoch 1 |  iter 1441 / 9295 | time 94[s] | loss 2.49
# | epoch 1 |  iter 1461 / 9295 | time 95[s] | loss 2.50
# | epoch 1 |  iter 1481 / 9295 | time 96[s] | loss 2.53
# | epoch 1 |  iter 1501 / 9295 | time 98[s] | loss 2.51
# | epoch 1 |  iter 1521 / 9295 | time 99[s] | loss 2.53
# | epoch 1 |  iter 1541 / 9295 | time 100[s] | loss 2.52
# | epoch 1 |  iter 1561 / 9295 | time 102[s] | loss 2.51
# | epoch 1 |  iter 1581 / 9295 | time 103[s] | loss 2.50
# | epoch 1 |  iter 1601 / 9295 | time 104[s] | loss 2.53
# | epoch 1 |  iter 1621 / 9295 | time 106[s] | loss 2.51
# | epoch 1 |  iter 1641 / 9295 | time 107[s] | loss 2.51
# | epoch 1 |  iter 1661 / 9295 | time 108[s] | loss 2.48
# | epoch 1 |  iter 1681 / 9295 | time 110[s] | loss 2.53
# | epoch 1 |  iter 1701 / 9295 | time 111[s] | loss 2.52
# | epoch 1 |  iter 1721 / 9295 | time 112[s] | loss 2.51
# | epoch 1 |  iter 1741 / 9295 | time 113[s] | loss 2.52
# | epoch 1 |  iter 1761 / 9295 | time 115[s] | loss 2.51
# | epoch 1 |  iter 1781 / 9295 | time 116[s] | loss 2.53
# | epoch 1 |  iter 1801 / 9295 | time 117[s] | loss 2.46
# | epoch 1 |  iter 1821 / 9295 | time 118[s] | loss 2.51
# | epoch 1 |  iter 1841 / 9295 | time 120[s] | loss 2.47
# | epoch 1 |  iter 1861 / 9295 | time 121[s] | loss 2.47
# | epoch 1 |  iter 1881 / 9295 | time 122[s] | loss 2.51
# | epoch 1 |  iter 1901 / 9295 | time 123[s] | loss 2.48
# | epoch 1 |  iter 1921 / 9295 | time 125[s] | loss 2.49
# | epoch 1 |  iter 1941 / 9295 | time 126[s] | loss 2.49
# | epoch 1 |  iter 1961 / 9295 | time 127[s] | loss 2.49
# | epoch 1 |  iter 1981 / 9295 | time 128[s] | loss 2.49
# | epoch 1 |  iter 2001 / 9295 | time 129[s] | loss 2.50
# | epoch 1 |  iter 2021 / 9295 | time 130[s] | loss 2.45
# | epoch 1 |  iter 2041 / 9295 | time 131[s] | loss 2.50
# | epoch 1 |  iter 2061 / 9295 | time 133[s] | loss 2.52
# | epoch 1 |  iter 2081 / 9295 | time 134[s] | loss 2.48
# | epoch 1 |  iter 2101 / 9295 | time 135[s] | loss 2.50
# | epoch 1 |  iter 2121 / 9295 | time 136[s] | loss 2.50
# | epoch 1 |  iter 2141 / 9295 | time 137[s] | loss 2.51
# | epoch 1 |  iter 2161 / 9295 | time 139[s] | loss 2.47
# | epoch 1 |  iter 2181 / 9295 | time 140[s] | loss 2.48
# | epoch 1 |  iter 2201 / 9295 | time 141[s] | loss 2.46
# | epoch 1 |  iter 2221 / 9295 | time 142[s] | loss 2.47
# | epoch 1 |  iter 2241 / 9295 | time 143[s] | loss 2.46
# | epoch 1 |  iter 2261 / 9295 | time 144[s] | loss 2.47
# | epoch 1 |  iter 2281 / 9295 | time 145[s] | loss 2.47
# | epoch 1 |  iter 2301 / 9295 | time 147[s] | loss 2.48
# | epoch 1 |  iter 2321 / 9295 | time 148[s] | loss 2.46
# | epoch 1 |  iter 2341 / 9295 | time 149[s] | loss 2.49
# | epoch 1 |  iter 2361 / 9295 | time 150[s] | loss 2.52
# | epoch 1 |  iter 2381 / 9295 | time 151[s] | loss 2.51
# | epoch 1 |  iter 2401 / 9295 | time 152[s] | loss 2.48
# | epoch 1 |  iter 2421 / 9295 | time 154[s] | loss 2.46
# | epoch 1 |  iter 2441 / 9295 | time 155[s] | loss 2.47
# | epoch 1 |  iter 2461 / 9295 | time 156[s] | loss 2.48
# | epoch 1 |  iter 2481 / 9295 | time 157[s] | loss 2.47
# | epoch 1 |  iter 2501 / 9295 | time 158[s] | loss 2.45
# | epoch 1 |  iter 2521 / 9295 | time 159[s] | loss 2.51
# | epoch 1 |  iter 2541 / 9295 | time 161[s] | loss 2.46
# | epoch 1 |  iter 2561 / 9295 | time 162[s] | loss 2.47
# | epoch 1 |  iter 2581 / 9295 | time 163[s] | loss 2.47
# | epoch 1 |  iter 2601 / 9295 | time 164[s] | loss 2.44
# | epoch 1 |  iter 2621 / 9295 | time 165[s] | loss 2.48
# | epoch 1 |  iter 2641 / 9295 | time 166[s] | loss 2.50
# | epoch 1 |  iter 2661 / 9295 | time 167[s] | loss 2.45
# | epoch 1 |  iter 2681 / 9295 | time 169[s] | loss 2.47
# | epoch 1 |  iter 2701 / 9295 | time 170[s] | loss 2.47
# | epoch 1 |  iter 2721 / 9295 | time 172[s] | loss 2.51
# | epoch 1 |  iter 2741 / 9295 | time 173[s] | loss 2.45
# | epoch 1 |  iter 2761 / 9295 | time 174[s] | loss 2.48
# | epoch 1 |  iter 2781 / 9295 | time 175[s] | loss 2.45
# | epoch 1 |  iter 2801 / 9295 | time 176[s] | loss 2.45
# | epoch 1 |  iter 2821 / 9295 | time 177[s] | loss 2.45
# | epoch 1 |  iter 2841 / 9295 | time 178[s] | loss 2.48
# | epoch 1 |  iter 2861 / 9295 | time 180[s] | loss 2.47
# | epoch 1 |  iter 2881 / 9295 | time 181[s] | loss 2.46
# | epoch 1 |  iter 2901 / 9295 | time 182[s] | loss 2.46
# | epoch 1 |  iter 2921 / 9295 | time 183[s] | loss 2.44
# | epoch 1 |  iter 2941 / 9295 | time 184[s] | loss 2.49
# | epoch 1 |  iter 2961 / 9295 | time 186[s] | loss 2.48
# | epoch 1 |  iter 2981 / 9295 | time 187[s] | loss 2.42
# | epoch 1 |  iter 3001 / 9295 | time 188[s] | loss 2.48
# | epoch 1 |  iter 3021 / 9295 | time 189[s] | loss 2.45
# | epoch 1 |  iter 3041 / 9295 | time 190[s] | loss 2.45
# | epoch 1 |  iter 3061 / 9295 | time 191[s] | loss 2.45
# | epoch 1 |  iter 3081 / 9295 | time 192[s] | loss 2.42
# | epoch 1 |  iter 3101 / 9295 | time 194[s] | loss 2.47
# | epoch 1 |  iter 3121 / 9295 | time 195[s] | loss 2.47
# | epoch 1 |  iter 3141 / 9295 | time 196[s] | loss 2.42
# | epoch 1 |  iter 3161 / 9295 | time 197[s] | loss 2.44
# | epoch 1 |  iter 3181 / 9295 | time 198[s] | loss 2.46
# | epoch 1 |  iter 3201 / 9295 | time 199[s] | loss 2.43
# | epoch 1 |  iter 3221 / 9295 | time 201[s] | loss 2.43
# | epoch 1 |  iter 3241 / 9295 | time 202[s] | loss 2.43
# | epoch 1 |  iter 3261 / 9295 | time 203[s] | loss 2.41
# | epoch 1 |  iter 3281 / 9295 | time 204[s] | loss 2.45
# | epoch 1 |  iter 3301 / 9295 | time 205[s] | loss 2.44
# | epoch 1 |  iter 3321 / 9295 | time 206[s] | loss 2.42
# | epoch 1 |  iter 3341 / 9295 | time 208[s] | loss 2.43
# | epoch 1 |  iter 3361 / 9295 | time 209[s] | loss 2.41
# | epoch 1 |  iter 3381 / 9295 | time 210[s] | loss 2.44
# | epoch 1 |  iter 3401 / 9295 | time 211[s] | loss 2.41
# | epoch 1 |  iter 3421 / 9295 | time 212[s] | loss 2.47
# | epoch 1 |  iter 3441 / 9295 | time 214[s] | loss 2.46
# | epoch 1 |  iter 3461 / 9295 | time 215[s] | loss 2.43
# | epoch 1 |  iter 3481 / 9295 | time 216[s] | loss 2.41
# | epoch 1 |  iter 3501 / 9295 | time 217[s] | loss 2.45
# | epoch 1 |  iter 3521 / 9295 | time 219[s] | loss 2.42
# | epoch 1 |  iter 3541 / 9295 | time 220[s] | loss 2.45
# | epoch 1 |  iter 3561 / 9295 | time 221[s] | loss 2.43
# | epoch 1 |  iter 3581 / 9295 | time 222[s] | loss 2.45
# | epoch 1 |  iter 3601 / 9295 | time 223[s] | loss 2.41
# | epoch 1 |  iter 3621 / 9295 | time 224[s] | loss 2.42
# | epoch 1 |  iter 3641 / 9295 | time 225[s] | loss 2.42
# | epoch 1 |  iter 3661 / 9295 | time 227[s] | loss 2.40
# | epoch 1 |  iter 3681 / 9295 | time 228[s] | loss 2.39
# | epoch 1 |  iter 3701 / 9295 | time 229[s] | loss 2.43
# | epoch 1 |  iter 3721 / 9295 | time 230[s] | loss 2.38
# | epoch 1 |  iter 3741 / 9295 | time 231[s] | loss 2.39
# | epoch 1 |  iter 3761 / 9295 | time 232[s] | loss 2.42
# | epoch 1 |  iter 3781 / 9295 | time 234[s] | loss 2.41
# | epoch 1 |  iter 3801 / 9295 | time 235[s] | loss 2.39
# | epoch 1 |  iter 3821 / 9295 | time 236[s] | loss 2.42
# | epoch 1 |  iter 3841 / 9295 | time 237[s] | loss 2.39
# | epoch 1 |  iter 3861 / 9295 | time 238[s] | loss 2.42
# | epoch 1 |  iter 3881 / 9295 | time 240[s] | loss 2.41
# | epoch 1 |  iter 3901 / 9295 | time 241[s] | loss 2.42
# | epoch 1 |  iter 3921 / 9295 | time 242[s] | loss 2.42
# | epoch 1 |  iter 3941 / 9295 | time 243[s] | loss 2.41
# | epoch 1 |  iter 3961 / 9295 | time 244[s] | loss 2.40
# | epoch 1 |  iter 3981 / 9295 | time 245[s] | loss 2.41
# | epoch 1 |  iter 4001 / 9295 | time 247[s] | loss 2.39
# | epoch 1 |  iter 4021 / 9295 | time 248[s] | loss 2.39
# | epoch 1 |  iter 4041 / 9295 | time 249[s] | loss 2.42
# | epoch 1 |  iter 4061 / 9295 | time 250[s] | loss 2.39
# | epoch 1 |  iter 4081 / 9295 | time 252[s] | loss 2.43
# | epoch 1 |  iter 4101 / 9295 | time 253[s] | loss 2.40
# | epoch 1 |  iter 4121 / 9295 | time 254[s] | loss 2.38
# | epoch 1 |  iter 4141 / 9295 | time 255[s] | loss 2.40
# | epoch 1 |  iter 4161 / 9295 | time 256[s] | loss 2.39
# | epoch 1 |  iter 4181 / 9295 | time 257[s] | loss 2.39
# | epoch 1 |  iter 4201 / 9295 | time 259[s] | loss 2.41
# | epoch 1 |  iter 4221 / 9295 | time 260[s] | loss 2.40
# | epoch 1 |  iter 4241 / 9295 | time 261[s] | loss 2.40
# | epoch 1 |  iter 4261 / 9295 | time 262[s] | loss 2.39
# | epoch 1 |  iter 4281 / 9295 | time 263[s] | loss 2.38
# | epoch 1 |  iter 4301 / 9295 | time 264[s] | loss 2.41
# | epoch 1 |  iter 4321 / 9295 | time 266[s] | loss 2.39
# | epoch 1 |  iter 4341 / 9295 | time 267[s] | loss 2.38
# | epoch 1 |  iter 4361 / 9295 | time 268[s] | loss 2.41
# | epoch 1 |  iter 4381 / 9295 | time 270[s] | loss 2.37
# | epoch 1 |  iter 4401 / 9295 | time 271[s] | loss 2.39
# | epoch 1 |  iter 4421 / 9295 | time 272[s] | loss 2.38
# | epoch 1 |  iter 4441 / 9295 | time 273[s] | loss 2.36
# | epoch 1 |  iter 4461 / 9295 | time 274[s] | loss 2.40
# | epoch 1 |  iter 4481 / 9295 | time 275[s] | loss 2.38
# | epoch 1 |  iter 4501 / 9295 | time 277[s] | loss 2.39
# | epoch 1 |  iter 4521 / 9295 | time 278[s] | loss 2.38
# | epoch 1 |  iter 4541 / 9295 | time 279[s] | loss 2.37
# | epoch 1 |  iter 4561 / 9295 | time 280[s] | loss 2.36
# | epoch 1 |  iter 4581 / 9295 | time 282[s] | loss 2.34
# | epoch 1 |  iter 4601 / 9295 | time 283[s] | loss 2.35
# | epoch 1 |  iter 4621 / 9295 | time 284[s] | loss 2.40
# | epoch 1 |  iter 4641 / 9295 | time 285[s] | loss 2.36
# | epoch 1 |  iter 4661 / 9295 | time 286[s] | loss 2.37
# | epoch 1 |  iter 4681 / 9295 | time 288[s] | loss 2.39
# | epoch 1 |  iter 4701 / 9295 | time 289[s] | loss 2.35
# | epoch 1 |  iter 4721 / 9295 | time 290[s] | loss 2.39
# | epoch 1 |  iter 4741 / 9295 | time 291[s] | loss 2.34
# | epoch 1 |  iter 4761 / 9295 | time 293[s] | loss 2.39
# | epoch 1 |  iter 4781 / 9295 | time 294[s] | loss 2.40
# | epoch 1 |  iter 4801 / 9295 | time 295[s] | loss 2.40
# | epoch 1 |  iter 4821 / 9295 | time 296[s] | loss 2.35
# | epoch 1 |  iter 4841 / 9295 | time 297[s] | loss 2.36
# | epoch 1 |  iter 4861 / 9295 | time 298[s] | loss 2.34
# | epoch 1 |  iter 4881 / 9295 | time 300[s] | loss 2.36
# | epoch 1 |  iter 4901 / 9295 | time 301[s] | loss 2.40
# | epoch 1 |  iter 4921 / 9295 | time 302[s] | loss 2.34
# | epoch 1 |  iter 4941 / 9295 | time 303[s] | loss 2.37
# | epoch 1 |  iter 4961 / 9295 | time 305[s] | loss 2.38
# | epoch 1 |  iter 4981 / 9295 | time 306[s] | loss 2.35
# | epoch 1 |  iter 5001 / 9295 | time 307[s] | loss 2.36
# | epoch 1 |  iter 5021 / 9295 | time 308[s] | loss 2.36
# | epoch 1 |  iter 5041 / 9295 | time 310[s] | loss 2.35
# | epoch 1 |  iter 5061 / 9295 | time 311[s] | loss 2.34
# | epoch 1 |  iter 5081 / 9295 | time 312[s] | loss 2.34
# | epoch 1 |  iter 5101 / 9295 | time 313[s] | loss 2.36
# | epoch 1 |  iter 5121 / 9295 | time 315[s] | loss 2.35
# | epoch 1 |  iter 5141 / 9295 | time 316[s] | loss 2.37
# | epoch 1 |  iter 5161 / 9295 | time 317[s] | loss 2.33
# | epoch 1 |  iter 5181 / 9295 | time 318[s] | loss 2.34
# | epoch 1 |  iter 5201 / 9295 | time 320[s] | loss 2.37
# | epoch 1 |  iter 5221 / 9295 | time 321[s] | loss 2.33
# | epoch 1 |  iter 5241 / 9295 | time 322[s] | loss 2.40
# | epoch 1 |  iter 5261 / 9295 | time 323[s] | loss 2.33
# | epoch 1 |  iter 5281 / 9295 | time 324[s] | loss 2.36
# | epoch 1 |  iter 5301 / 9295 | time 326[s] | loss 2.36
# | epoch 1 |  iter 5321 / 9295 | time 327[s] | loss 2.36
# | epoch 1 |  iter 5341 / 9295 | time 328[s] | loss 2.36
# | epoch 1 |  iter 5361 / 9295 | time 330[s] | loss 2.33
# | epoch 1 |  iter 5381 / 9295 | time 331[s] | loss 2.37
# | epoch 1 |  iter 5401 / 9295 | time 332[s] | loss 2.36
# | epoch 1 |  iter 5421 / 9295 | time 333[s] | loss 2.34
# | epoch 1 |  iter 5441 / 9295 | time 335[s] | loss 2.34
# | epoch 1 |  iter 5461 / 9295 | time 336[s] | loss 2.41
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 40>()
#      37 trainer = Trainer(model, optimizer)
#      39 # 学習開始
# ---> 40 trainer.fit(contexts, target, max_epoch, batch_size)
#      41 trainer.plot()
#      43 # 後ほど利用できるように、必要なデータを保存
#
# File ~\OneDrive\デスクトップ\勉強会\ぜろつく２\deep-learning-from-scratch-2-master\ch04\..\common\trainer.py:39, in Trainer.fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      36 batch_t = t[iters*batch_size:(iters+1)*batch_size]
#      38 # 勾配を求め、パラメータを更新
# ---> 39 loss = model.forward(batch_x, batch_t)
#      40 model.backward()
#      41 params, grads = remove_duplicate(model.params, model.grads)  # 共有された重みを1つに集約
#
# File ~\OneDrive\デスクトップ\勉強会\ぜろつく２\deep-learning-from-scratch-2-master\ch04\cbow.py:39, in CBOW.forward(self, contexts, target)
#      37     h += layer.forward(contexts[:, i])
#      38 h *= 1 / len(self.in_layers)
# ---> 39 loss = self.ns_loss.forward(h, target)
#      40 return loss
#
# File ~\OneDrive\デスクトップ\勉強会\ぜろつく２\deep-learning-from-scratch-2-master\ch04\..\ch04\negative_sampling_layer.py:88, in NegativeSamplingLoss.forward(self, h, target)
#      86 def forward(self, h, target):
#      87     batch_size = target.shape[0]
# ---> 88     negative_sample = self.sampler.get_negative_sample(target)
#      90     # 正例のフォワード
#      91     score = self.embed_dot_layers[0].forward(h, target)
#
# File ~\OneDrive\デスクトップ\勉強会\ぜろつく２\deep-learning-from-scratch-2-master\ch04\..\ch04\negative_sampling_layer.py:64, in UnigramSampler.get_negative_sample(self, target)
#      62         p[target_idx] = 0
#      63         p /= p.sum()
# ---> 64         negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
#      65 else:
#      66     # GPU(cupy）で計算するときは、速度を優先
#      67     # 負例にターゲットが含まれるケースがある
#      68     negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
#      69                                        replace=True, p=self.word_p)
#
# File mtrand.pyx:981, in numpy.random.mtrand.RandomState.choice()
#
# File <__array_function__ internals>:2, in cumsum(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
import sys
sys.path.append('..')
from common.util import most_similar, analogy
import pickle


pkl_file = 'cbow_params.pkl'
# pkl_file = 'skipgram_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# most similar task
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)

# analogy task
print('-'*50)
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875
#
# [query] toyota
#  ford: 0.55078125
#  instrumentation: 0.509765625
#  mazda: 0.49365234375
#  bethlehem: 0.47509765625
#  nissan: 0.474853515625
# --------------------------------------------------
#
# [analogy] king:man = queen:?
#  woman: 5.16015625
#  veto: 4.9296875
#  ounce: 4.69140625
#  earthquake: 4.6328125
#  successor: 4.609375
#
# [analogy] take:took = go:?
#  went: 4.55078125
#  points: 4.25
#  began: 4.09375
#  comes: 3.98046875
#  oct.: 3.90625
#
# [analogy] car:cars = child:?
#  children: 5.21875
#  average: 4.7265625
#  yield: 4.20703125
#  cattle: 4.1875
#  priced: 4.1796875
#
# [analogy] good:better = bad:?
#  more: 6.6484375
#  less: 6.0625
#  rather: 5.21875
#  slower: 4.734375
#  greater: 4.671875
